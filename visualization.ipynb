# %%
from functions import *
import numpy as np

# %%
# Loading data files

# embeddings
embeddings = pd.read_csv("csv_files/embeddings.csv")
embeddings2d = pd.read_csv("csv_files/embeddings2D.csv")

# kmeans clusters
clusters = pd.read_csv("csv_files/kmeansClusters.csv")

# %%
from matplotlib import colormaps
list(colormaps)
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
#  'Set1',
#  'Set2',
#  'Set3',
#  'tab10',
#  'tab20',
#  'tab20b',
#  'tab20c',
#  'grey',
#  'gist_grey',
#  'gist_yerg',
#  'Grays',
#  'magma_r',
#  'inferno_r',
#  'plasma_r',
#  'viridis_r',
#  'cividis_r',
#  'twilight_r',
#  'twilight_shifted_r',
#  'turbo_r',
#  'Blues_r',
#  'BrBG_r',
#  'BuGn_r',
#  'BuPu_r',
#  'CMRmap_r',
#  'GnBu_r',
#  'Greens_r',
#  'Greys_r',
#  'OrRd_r',
#  'Oranges_r',
#  'PRGn_r',
#  'PiYG_r',
#  'PuBu_r',
#  'PuBuGn_r',
#  'PuOr_r',
#  'PuRd_r',
#  'Purples_r',
#  'RdBu_r',
#  'RdGy_r',
#  'RdPu_r',
#  'RdYlBu_r',
#  'RdYlGn_r',
#  'Reds_r',
#  'Spectral_r',
#  'Wistia_r',
#  'YlGn_r',
#  'YlGnBu_r',
#  'YlOrBr_r',
#  'YlOrRd_r',
#  'afmhot_r',
#  'autumn_r',
#  'binary_r',
#  'bone_r',
#  'brg_r',
#  'bwr_r',
#  'cool_r',
#  'coolwarm_r',
#  'copper_r',
#  'cubehelix_r',
#  'flag_r',
#  'gist_earth_r',
#  'gist_gray_r',
#  'gist_heat_r',
#  'gist_ncar_r',
#  'gist_rainbow_r',
#  'gist_stern_r',
#  'gist_yarg_r',
#  'gnuplot_r',
#  'gnuplot2_r',
#  'gray_r',
#  'hot_r',
#  'hsv_r',
#  'jet_r',
#  'nipy_spectral_r',
#  'ocean_r',
#  'pink_r',
#  'prism_r',
#  'rainbow_r',
#  'seismic_r',
#  'spring_r',
#  'summer_r',
#  'terrain_r',
#  'winter_r',
#  'Accent_r',
#  'Dark2_r',
#  'Paired_r',
#  'Pastel1_r',
#  'Pastel2_r',
#  'Set1_r',
#  'Set2_r',
#  'Set3_r',
#  'tab10_r',
#  'tab20_r',
#  'tab20b_r',
#  'tab20c_r']

# %%
# Showing Inertias of kmeans
kmeansToTest = range(10,35)
clusterDf = doKmeans(embeddings,kmeansToTest,showIntertias=True)

# %%
# 2D visualization of clusters
import matplotlib.cm as cm

# number of clusters to test
clusterNum = 17

# colors and title
colors = cm.plasma(np.linspace(0, 1, clusterNum))
plt.title("2D Cluster Representation")

#scatter each cluster with the appropriate color
for cluster in range(clusterNum):
    indexList = clusters.index[clusters['Kmeans '+str(clusterNum)] == cluster].tolist()
    this = embeddings2d.iloc[indexList]
    plt.scatter(this['0'],this['1'],color = colors[cluster],label="Cluster "+str(cluster))

# add legend and show graph
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.style.use("dark_background")
plt.show()

# %%
# retrieve specific cluster data from a cluster number
printClusterSet(clusterDf,25)
# Out:
# Printing 25 cluster set:
#
# Cluster 0
#                                   Description  Kmeans 25
# 42                                    triples          0
# 67                                       dots          0
# 76                                one element          0
# 78                             three elements          0
# 79                              four elements          0
# ...                                       ...        ...
# 68897                              3 elemente          0
# 68940         3 independent points of contact          0
# 68941  3 points of contact with intersections          0
# 69011                               has a dot          0
# 69018             avec un ou plusieurs points          0
#
# [4184 rows x 2 columns]
#
#
#
# Cluster 1
#                             Description  Kmeans 25
# 186                      crossing lines          1
# 267              contains crossed lines          1
# 334    even number crossing middle line          1
# 507                  intersecting lines          1
# 591                      crossing lines          1
# ...                                 ...        ...
# 68427                     crossed lines          1
# 68433                     crossed lines          1
# 68460               lines cross through          1
# 68731                     crossed lines          1
# 68834                lines not crossing          1
#
# [1158 rows x 2 columns]
#
#
#
# Cluster 2
#                                           Description  Kmeans 25
# 10                       can be written in one stroke          2
# 127                   single stroke, no doubling back          2
# 210    have exactly two strokes facing straight down           2
# 224                                single open stroke          2
# 237                         single stroke, dont close          2
# ...                                               ...        ...
# 68426                           [inverted] one stroke          2
# 68432                                      one stroke          2
# 68895                                         strokes          2
# 68896                                   cross strokes          2
# 68915             only one stroke but no closed loops          2
#
# [1093 rows x 2 columns]
#
#
#
# Cluster 3
#                               Description  Kmeans 25
# 24                      an enclosed space          3
# 63                       an enclosed area          3
# 110                         enclosed area          3
# 257      contains a closed internal space          3
# 447                         enclosed area          3
# ...                                   ...        ...
# 68949  actual enclosed space with 3 sides          3
# 68987                      encloses space          3
# 68997          all form an enclosed space          3
# 69003              has one enclosed space          3
# 69006          creates one enclosed space          3
#
# [2007 rows x 2 columns]
#
#
#
# Cluster 4
#                                              Description  Kmeans 25
# 52                                        two components          4
# 77                                          two elements          4
# 128                           three unconnected elements          4
# 129                             two unconnected elements          4
# 206                                              2 piece          4
# ...                                                  ...        ...
# 68415                                    separated parts          4
# 68429                                    separated parts          4
# 68553  all parts are connected, no part is off by itself          4
# 68635                                         two pieces          4
# 68942                    number of independent parts = 5          4
#
# [1021 rows x 2 columns]
#
#
#
# Cluster 5
#                                 Description  Kmeans 25
# 20                  totally enclosed shapes          5
# 61               completely enclosed shapes          5
# 120                            v or u shape          5
# 121                            closed shape          5
# 123                            closed shape          5
# ...                                     ...        ...
# 68906  open linear shapes with acute angles          5
# 68959              a rectangle on the right          5
# 68960          a parallel rectangle on left          5
# 68990     two dots spanning the main shape.          5
# 69025               look like common shapes          5
#
# [1901 rows x 2 columns]
#
#
#
# Cluster 6
#                                              Description  Kmeans 25
# 116                                  only straight lines          6
# 117                                    only curved lines          6
# 133                                  straight lines only          6
# 175                              strictly straight lines          6
# 190                                  only straight lines          6
# ...                                                  ...        ...
# 68536                                     straight lines          6
# 68554                anything with plain straight lines.          6
# 68664                   they all must have straight line          6
# 68710                                      straight line          6
# 68999  characters comprised only of straight (non-cur...          6
#
# [1241 rows x 2 columns]
#
#
#
# Cluster 7
#                                              Description  Kmeans 25
# 3                                    triangle and circle          7
# 4                                         triangle and e          7
# 43                                             triangles          7
# 98                                   contains a triangle          7
# 113                              three sides of a square          7
# ...                                                  ...        ...
# 68921               caractères rentrant dans un triangle          7
# 68932                       at least 2 sides of triangle          7
# 68948                                at least 1 triangle          7
# 68998  the center shape is connected to the top triangle          7
# 69008                                 vertical triangles          7
#
# [901 rows x 2 columns]
#
#
#
# Cluster 8
#                           Description  Kmeans 25
# 66                        has curves           8
# 72                    includes curves          8
# 96                  single open curve          8
# 106                         no curves          8
# 107    curve greater than 180 degrees          8
# ...                               ...        ...
# 69001                 contain a curve          8
# 69007                          curved          8
# 69010               has a curved line          8
# 69015                         courbes          8
# 69026  made of both lines and curves.          8
#
# [2662 rows x 2 columns]
#
#
#
# Cluster 9
#                  Description  Kmeans 25
# 0                        ben          9
# 2                        gos          9
# 5                         zh          9
# 6           alpha beta gamma          9
# 7                  alpha psy          9
# ...                      ...        ...
# 68967         les 6 en début          9
# 68968                  les u          9
# 68988                  has w          9
# 69013  présente des arrondis          9
# 69019          un seul trait          9
#
# [9124 rows x 2 columns]
#
#
#
# Cluster 10
#                                              Description  Kmeans 25
# 497                       180-degree rotational symmetry         10
# 2240                          axe de symétrie horizontal         10
# 2506                                   symetrie rotative         10
# 2826   le graphe possède un axe ou un point de symétrie.         10
# 4300               le graphe possède un axe de symétrie.         10
# ...                                                  ...        ...
# 68355                                   axis of symmetry         10
# 68374                                   axis of symmetry         10
# 68393                                   axis of symmetry         10
# 68422                                   axis of symmetry         10
# 68428                                   axis of symmetry         10
#
# [784 rows x 2 columns]
#
#
#
# Cluster 11
#                                              Description  Kmeans 25
# 90                                  has an unbroken loop         11
# 94                                contains a closed loop         11
# 95                                  contains close loops         11
# 100                                 no branches or loops         11
# 104                                     node but no loop         11
# ...                                                  ...        ...
# 67666                         curlies - has a small loop         11
# 68561      has a loop or an opening that looks like an a         11
# 68597  lower case n with no line behind it regular lo...         11
# 68648                                2, j, face, c, loop         11
# 68917                                       closed loops         11
#
# [950 rows x 2 columns]
#
#
#
# Cluster 12
#                                              Description  Kmeans 25
# 23     characters likely drawn in a single motion wit...         12
# 122                    rotate to create a similar letter         12
# 152                               written in two strokes         12
# 213                                   oblique characters         12
# 249    this letter contains a line that is exactly du...         12
# ...                                                  ...        ...
# 68924       caractères avec au moins une barre verticale         12
# 68969  tous les caractères comportant au moins une li...         12
# 68970  tous les caractères composés de deux droites, ...         12
# 68991                                   dotted variants.         12
# 68992                             character(s) with dots         12
#
# [8665 rows x 2 columns]
#
#
#
# Cluster 13
#                                    Description  Kmeans 25
# 172                          vertical symmetry         13
# 491           symmetrical across vertical axis         13
# 495          symmetrical through vertical axis         13
# 625     either horizontal or vertical symmetry         13
# 714    vertical symmetry without vertical line         13
# ...                                        ...        ...
# 68337                        vertical symmetry         13
# 68373                        vertical symmetry         13
# 68379                        vertical symmetry         13
# 68394                        vertical symmetry         13
# 69012          has a vertical line of symmetry         13
#
# [1145 rows x 2 columns]
#
#
#
# Cluster 14
#                                          Description  Kmeans 25
# 27     dreieck-struktur / winkel kleiner als 90 grad         14
# 28                         beendet durch zwei kreise         14
# 29                        durch keine kreise beendet         14
# 31                                        zwei hügel         14
# 36                                    strike through         14
# ...                                              ...        ...
# 68995  all could be drawn without picking up the pen         14
# 69017         lignes qui se croisent, ou se touchent         14
# 69020                            en forme de crochet         14
# 69023                                        boucles         14
# 69024                   avec une barre sur le dessus         14
#
# [8563 rows x 2 columns]
#
#
#
# Cluster 15
#                                 Description  Kmeans 25
# 8                          one closed space         15
# 18         an enlosed area open at the base         15
# 37                                two holes         15
# 46                     oral and nasal stops         15
# 142                                   holes         15
# ...                                     ...        ...
# 68777              have holes in the center         15
# 68811                       a round opening         15
# 68866                           signe fermé         15
# 68913                                  hole         15
# 69021  fermée, mais qui nest pas une boucle         15
#
# [2448 rows x 2 columns]
#
#
#
# Cluster 16
#                                     Description  Kmeans 25
# 21                     protrusions on the right         16
# 22                       protusions on the left         16
# 58               pointed edge in the top center         16
# 62       characters pointing horizontally right         16
# 85            top right to bottom left diagonal         16
# ...                                         ...        ...
# 68886                             rechte winkel         16
# 68950  3 sides of a square, but missing 4th leg         16
# 68958                       a flag on top right         16
# 68961            a half line on the bottom left         16
# 68964                     square on bottom left         16
#
# [3847 rows x 2 columns]
#
#
#
# Cluster 17
#                                        Description  Kmeans 25
# 12                            angles < 90 degrees          17
# 35                                  ángulos rectos         17
# 50                                      left angle         17
# 65                  all right angles or no angles          17
# 84                                 opposing arrows         17
# ...                                            ...        ...
# 68544       looks like upside-down smiles or faces         17
# 68571                                  upside down         17
# 68802                                  upside down         17
# 68904                   has rotated 45 deg squares         17
# 69016  avec des angles qui ne sont pas à 90 degrés         17
#
# [1556 rows x 2 columns]
#
#
#
# Cluster 18
#                                   Description  Kmeans 25
# 13                     three horizontal lines         18
# 25       exactly two (non-intersecting) lines         18
# 33     die linie beugt sich und wird parallel         18
# 60                            diagnonal lines         18
# 99                             parallel lines         18
# ...                                       ...        ...
# 68989                    close parallel lines         18
# 68996                 pairs of parallel lines         18
# 69000          three horizontal line segments         18
# 69002            contains 3 unconnected lines         18
# 69004            contains 2 unconnected lines         18
#
# [3003 rows x 2 columns]
#
#
#
# Cluster 19
#                                              Description  Kmeans 25
# 283                         are different when mirrored          19
# 655                                   mirror image pairs         19
# 847                         similar/exact reflected pair         19
# 1158   two pair of are reflections/opposites of one a...         19
# 1388   which mirror vertically to create another char...         19
# ...                                                  ...        ...
# 68378                                      mirror images         19
# 68382                                      mirror images         19
# 68387                                      mirror images         19
# 68400                                      mirror images         19
# 68435                                      mirror images         19
#
# [578 rows x 2 columns]
#
#
#
# Cluster 20
#                                              Description  Kmeans 25
# 45                                     vowels/diphthongs         20
# 56                                             consonnes         20
# 198    looks identical to letters in the english alph...         20
# 240                                            not roman         20
# 253    are taller than the standard height of most le...         20
# ...                                                  ...        ...
# 68887                            look like latin letters         20
# 68899                            look like latin letters         20
# 68909                                      greek letters         20
# 68912   english looking letters, made differently though         20
# 68931                                    latin and greek         20
#
# [2037 rows x 2 columns]
#
#
#
# Cluster 21
#                                              Description  Kmeans 25
# 38                      trazos verticales u horizontales         21
# 44                                         perpendicular         21
# 51                                          downward dot         21
# 73                                         vertical only         21
# 74                                       horizontal only         21
# ...                                                  ...        ...
# 68938                       at least 2 vertical segments         21
# 68952                    both different sloped diagonals         21
# 68981  topologically equivalent to a plain line, plus...         21
# 68986                   three distinct vertical sections         21
# 69014                                   a des diagonales         21
#
# [3774 rows x 2 columns]
#
#
#
# Cluster 22
#                                           Description  Kmeans 25
# 1                                       a full circle         22
# 9                                contains round parts         22
# 14                                        full circle         22
# 19             characters incuding circle-like shapes         22
# 34                                   rasgo redondeado         22
# ...                                               ...        ...
# 68835                                           round         22
# 68858  all need to at least have rounded areas on it.         22
# 68860                                  little circles         22
# 68884                          a circle or semicircle         22
# 68946                      semicircles but no circles         22
#
# [1742 rows x 2 columns]
#
#
#
# Cluster 23
#                                              Description  Kmeans 25
# 32                                horizontal symmetrisch         23
# 57                       first 11 left-to-right symmetry         23
# 108                        symmetrical about the horizon         23
# 167                                 horizontal symmetry          23
# 169                                  horizontal symmetry         23
# ...                                                  ...        ...
# 68736                                  all look similar          23
# 68916                            symmetrical in some way         23
# 68927  achsensymmetrisch bzgl waagerechter mitte nich...         23
# 69009                  has a horizontal line of symmetry         23
# 69022                         symétrique sur un des axes         23
#
# [1787 rows x 2 columns]
#
#
#
# Cluster 24
#                                              Description  Kmeans 25
# 11                                  perpendicular lines          24
# 17                            a horizontal straight line         24
# 40                                     has diagonal line         24
# 41                                       horizontal line         24
# 59                             horizontal straight lines         24
# ...                                                  ...        ...
# 68934                  at least 1 straight diagonal line         24
# 68951                         some kind of diagonal line         24
# 68971                             diagonal straight line         24
# 68993                                perpendicular lines         24
# 69005  has a horizontal line intersecting a vertical ...         24
#
# [2856 rows x 2 columns]
